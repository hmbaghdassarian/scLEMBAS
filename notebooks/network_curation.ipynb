# %%
data_path = '/nobackup/users/hmbaghda/scLEMBAS/tool/network'

# %% [markdown]
# # To Do:
# what signaling pathway network database to use (resource filter)omnipath does not exclusively have signaling network PPIs, but all PPIs
#
# follow Nikos' scripts

# %%
import networkx as nx

# %%
help(nx.shortest_paths.generic.has_path)
# Out:
# Help on function has_path in module networkx.algorithms.shortest_paths.generic:
#
# has_path(G, source, target)
#     Returns *True* if *G* has a path from *source* to *target*.
#
#     Parameters
#     ----------
#     G : NetworkX graph
#
#     source : node
#        Starting node for path
#
#     target : node
#        Ending node for path

# %%
# nikos_path = '/nobackup/users/hmbaghda/Software/DrugsANNSignaling/data'
# import os
# test = pd.read_csv(os.path.join(nikos_path, 'omnipath_webservice_interactions__recent.tsv'), sep = '\t')
