# %% [markdown]
# Given the results in 06Dii, here, we demonstrate that the encoder/bias portion alone cannot predict as well as the full LEMBAS pipeline. This rejects the notion that the stimulation information, which is not decoupled from the bias, is coming solely from the stochastic encoder and that the RNN portion is necessary.

# %% [markdown]
# <span style="color:red">TODO:</span>: prediction when weights are 0, prediction when bias isn't added in, and compare to actual prediction
